# %%
# !mkdir drive/My\ Drive/S13
# %cd /content/drive/My Drive/S13/YoloV3
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# /content/drive/My Drive/S13/YoloV3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cat data/custom_data/custom.data
# Out:
# classes = 1
# train = ./data/custom_data/train.txt
# valid = ./data/custom_data/test.txt
# names = ./data/custom_data/custom.names

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-04-26 13:55:43.073248: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 610.66it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 77.69it/s]
# ...

# %%
# %cat data/custom_data/custom.data
# Out:
# classes = 1
# train = ./data/custom_data/train.txt
# valid = ./data/custom_data/test.txt
# names = custom.names

# %%
# !python train.py --data data/custom_data/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
#    107/299     10.3G     0.953     0.683         0      1.64         5       512: 100% 37/37 [01:33<00:00,  2.54s/it]
#    107/299     10.3G     0.953     0.683         0      1.64         5       512: 100% 37/37 [01:33<00:00,  2.54s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 4/4 [00:03<00:00,  1.27it/s]
#                  all        40        40     0.984         1     0.995     0.992
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 4/4 [00:03<00:00,  1.27it/s]
#                  all        40        40     0.984         1     0.995     0.992
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    108/299     10.3G     0.977     0.695         0      1.67         6       512: 100% 37/37 [01:34<00:00,  2.54s/it]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_frame
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/custom_data/custom.names', output='out_frame', save_txt=False, source='./data/frame', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/1007 data/frame/image-001.png: 320x512 Done. (0.035s)
# image 2/1007 data/frame/image-002.png: 320x512 Done. (0.033s)
# image 3/1007 data/frame/image-003.png: 320x512 Done. (0.033s)
# image 4/1007 data/frame/image-004.png: 320x512 Done. (0.033s)
# image 5/1007 data/frame/image-005.png: 320x512 Done. (0.033s)
# image 6/1007 data/frame/image-006.png: 320x512 Done. (0.033s)
# image 7/1007 data/frame/image-007.png: 320x512 1 Fans, Done. (0.033s)
# image 8/1007 data/frame/image-008.png: 320x512 Done. (0.033s)
# ...

# %%
Image(filename='out_out/%[sandeep:base]-97.jpg', width=600)

# %%
Image(filename='out_out/%[sandeep:base]-240.jpg', width=600)

# %%
Image(filename='out_out/%[sandeep:base]-337.jpg', width=600)

# %%
Image(filename='out_out/img020.jpg', width=600)

# %%
# !python detect.py --conf-thres 0.1 --output out_out
